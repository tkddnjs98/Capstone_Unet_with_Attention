# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import math
import matplotlib.pyplot as plt
import PIL.Image as Image
import random
from tqdm import tqdm_notebook
from sklearn.cluster import DBSCAN
from tqdm import notebook
import cv2

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

from torch.utils.data import Dataset, DataLoader
from torchvision import transforms as transform
from torchvision.io import read_image
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/캡스톤기말프로젝트발표/archive.zip

# %%
import pandas as pd

# %%
data_read = pd.read_csv('/content/train.csv')
train_ID = data_read['ImageId'].tolist()
mask_ID = data_read['MaskId'].tolist()

# %%
class Potdataset(Dataset):
    def __init__(self, data_dir, masked_dir, transform = True, IMAGE_SIZE = 224, phase = 'train'):
        
        self.data_dir = data_dir
        self.masked_dir = masked_dir
        if phase == 'train':
          self.data_names = train_ID[:13000]
          self.masked_names = mask_ID[:13000]
        else:
          self.data_names = train_ID[13000:]
          self.masked_names = mask_ID[13000:]

        
        self.dataset_size = len(self.data_names)
        self.IMAGE_SIZE = IMAGE_SIZE
        self.transform = transform
        assert len(self.data_names) ==len(self.masked_names)
        
        
    def __len__(self):
        return self.dataset_size

    def __getitem__(self, idx):
        image = cv2.imread(os.path.join(self.data_dir+ '/images/' + self.data_names[idx]))
        image = cv2.resize(image, dsize = (self.IMAGE_SIZE, self.IMAGE_SIZE), interpolation = cv2.INTER_LINEAR)

        mask = cv2.imread(os.path.join(self.masked_dir+ '/masks/' + self.masked_names[idx]))
        mask = cv2.resize(mask, dsize = (self.IMAGE_SIZE, self.IMAGE_SIZE), interpolation = cv2.INTER_NEAREST)
        mask[mask < 240] = 0
        mask[mask >= 240] = 255
        mask = mask / 255

        mask_H, mask_W, mask_C = mask.shape
        background= np.ones(shape = (mask_H, mask_W))
        background[mask[..., 0] != 0] = 0
        background[mask[..., 1] != 0] = 0
        background[mask[..., 2] != 0] = 0
        mask = np.concatenate([np.expand_dims(background, axis = -1), mask], axis= -1)
        mask= np.argmax(mask, axis = -1)
      
        if self.transform:
          image = self.transform(image)
        target = torch.from_numpy(mask).long()
        return image, target

# %%
transform_image = transform.Compose([transform.ToTensor(),
                                      transform.Normalize([0.485, 0.485, 0.485], [0.229, 0.229, 0.229])])

# %%
data_dir = '/content/images'
label_dir = '/content/masks'

train_set = Potdataset(data_dir, label_dir, transform = transform_image, phase = 'train')
validation_set = Potdataset(data_dir, label_dir, transform = transform_image, phase = 'validation')

# %%
image, target = train_set[1000]

# %%
print(f'이미지의 크기: {image.shape}, 라벨의 크기: {target.shape}')
# Out:
# 이미지의 크기: torch.Size([3, 224, 224]), 라벨의 크기: torch.Size([224, 224])

# %% [markdown]
# 이미지는 [채널수, 행 크기, 열 크기]로 구성, 라벨은 [행의 크기, 열의 크기]
# 로 구성되어 있습니다.

# %%
plt.imshow(image.permute(1, 2, 0)* 255)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(target)

# %% [markdown]
# #배치형태로 이미지가 구성이 될때 배치를 어떻게 구성할 것이냐? 이미지, 라벨, maskdataset을 어떻게 미니배치 형태로 구성을 할 것인지 collate_function을 통해 dataloader을 통해 전달

# %% [markdown]
# 입력사진: [배치사이즈, 채널, 행 크기, 열 크기]
# 라벨: [배치사이즈, 행 크기, 열 크기]

# %%
def collate_fn(batch):  
  images = []
  targets = []
  for a, b in batch:
    images.append(a)
    targets.append(b)
  
  images = torch.stack(images, dim = 0)
  targets = torch.stack(targets, dim = 0)
  return images, targets

# %%
def build_dataloader(train_set, validation_set, batch_size = 4):
  dataloaders = {}
  dataloaders['train'] = DataLoader(train_set, batch_size = batch_size, shuffle = False, collate_fn = collate_fn)
  dataloaders['validation'] = DataLoader(validation_set, batch_size = batch_size, shuffle = False, collate_fn = collate_fn)
  return dataloaders

# %%
dataloaders = build_dataloader(train_set, validation_set, batch_size = 16)

# %% [markdown]
# dataloader을 훈련과 검증에 따른 수행을 다르게 하기 위해, key와 value를 가진 딕셔너리로 정의하였다.

# %% [markdown]
# #모델 정의하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Encoder-Decoder구조로 이루어진 Unet을 구현하려고 한다.
# - Encoder: Encoder로 이미지에서 유의미한 feature map을 형성합니다.
# - Decoder: 입력이미지에 해당하는 semantic한 정보를 upsampling하면서 segmentation결과를 만듭니다.

# %% [markdown]
# up conv: 원본이미지에서 기본 컨볼루션(곱 연산 누적 합)하면 컨볼루션을 한 결과값과 컨볼루션 필터 값을 가지고 역행렬을 구합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# skip connection: encoder에서 layer을 통과하면서 객체 정보는 많아지지만,
# resolution은 줄어듭니다. 이 상태로 up convolution을 하면, 원본 이미지 자세한   부분을 놓지게 됩니다.
#  모서리와 target과 차이를 최소화하기 위해 사용됩니다.

# %% [markdown]
# #기본 모듈 정의

# %%
def Convlayer(in_channels, out_channels):
  layers = nn.Sequential(
      nn.Conv2d(in_channels, out_channels, kernel_size = 3, padding = 1),
      nn.BatchNorm2d(out_channels),
      nn.ReLU(inplace = True),

      nn.Conv2d(out_channels, out_channels, kernel_size = 3, padding = 1),
      nn.BatchNorm2d(out_channels),
      nn.ReLU(inplace = True)
  )
  return layers

# %%
class spatial_attention(nn.Module):
  def __init__(self, in_channels):
    super().__init__()
    self.spatial = nn.Conv2d(in_channels, 1, kernel_size = 3, padding = 1)

  def forward(self, input):
    x = torch.sigmoid(self.spatial(input))
    return torch.mul(x, input)#마지막에 출력값과 입력값을 element-wise 곱을 하였다.

# %%
class channel_attention(nn.Module):
  def __init__(self, in_channels, r = 16):
    super().__init__()
    self.avg = nn.AdaptiveAvgPool2d((1,1))
    self.excitation = nn.Sequential(
        nn.Linear(in_channels, r),
        nn.ReLU(),
        nn.Linear(r, in_channels),
        nn.Sigmoid()
        )
    
  def forward(self, input):
    x = self.avg(input) #x.size([batch_size, channel_size, 1, 1])
    x = x.view(x.size(0), -1) #x.size([batch_size, channel_size])
    x = self.excitation(x)
    x = x.view(x.size(0), x.size(1), 1, 1)
    return torch.mul(x, input)

# %%
def attention_block(mode = "Spatial", input_dim = None, r = None):
    if mode == "Spatial":
        return spatial_attention(input_dim)
    elif mode == "Channel":
        return channel_attention(input_dim, r)
    
    else:
        return nn.Sequential()

# %%
def UpConvLayer(in_channels, out_channels):
  layers = nn.Sequential(
      nn.ConvTranspose2d(in_channels, out_channels, kernel_size = 2, stride = 2),
      nn.BatchNorm2d(out_channels),
      nn.ReLU(inplace = True)
  )
  return layers

# %% [markdown]
# #기본 Unet

# %%
class Encoder(nn.Module):
  def __init__(self,):
    super().__init__()
    self.conv_block1 = Convlayer(in_channels = 3, out_channels = 64)
    self.conv_block2 = Convlayer(in_channels = 64, out_channels = 128)
    self.conv_block3 = Convlayer(in_channels = 128, out_channels = 256)
    self.conv_block4 = Convlayer(in_channels = 256, out_channels = 512)
    self.conv_block5 = Convlayer(in_channels = 512, out_channels = 1024)
    self.pool = nn.MaxPool2d(kernel_size = 2)

  def forward(self, x):
    encode_features = []

    out = self.conv_block1(x)
    encode_features.append(out)
    out = self.pool(out)
  
    
    out = self.conv_block2(out)
    encode_features.append(out)
    out = self.pool(out)
    

    out = self.conv_block3(out)
    encode_features.append(out)
    out = self.pool(out)
    

    out = self.conv_block4(out)
    encode_features.append(out)
    out = self.pool(out)
    
  

    out = self.conv_block5(out)

    return out, encode_features

# %%
class Decoder(nn.Module):
  def __init__(self):
    super().__init__()
    self.upconv_layer1 = UpConvLayer(in_channels = 1024, out_channels = 512)
    self.conv_block1 =  Convlayer(in_channels = 1024, out_channels = 512)
    
    self.upconv_layer2 = UpConvLayer(in_channels = 512, out_channels = 256)
    self.conv_block2 =  Convlayer(in_channels = 512, out_channels = 256)

    self.upconv_layer3 = UpConvLayer(in_channels = 256, out_channels = 128)
    self.conv_block3 =  Convlayer(in_channels = 256, out_channels = 128)

    self.upconv_layer4 = UpConvLayer(in_channels = 128, out_channels = 64)
    self.conv_block4 =  Convlayer(in_channels = 128, out_channels = 64)
    

  def forward(self, x, encoder_features):
    out = self.upconv_layer1(x)
    out = torch.cat([out, encoder_features[-1]], dim = 1)
    out = self.conv_block1(out)

    out = self.upconv_layer2(out)
    out = torch.cat([out, encoder_features[-2]], dim = 1)
    out = self.conv_block2(out)

    out = self.upconv_layer3(out)
    out = torch.cat([out, encoder_features[-3]], dim = 1)
    out = self.conv_block3(out)
    
    out = self.upconv_layer4(out)
    out = torch.cat([out, encoder_features[-4]], dim = 1)
    out = self.conv_block4(out)

  

    return out

# %%
class Unet(nn.Module):
  def __init__(self, num_classes):
    super().__init__()
    self.encoder = Encoder()
    self.decoder = Decoder()
    self.head= nn.Conv2d(64, num_classes, kernel_size = 1, padding = 0)
  
  def forward(self, x):
    out, encode_features = self.encoder(x)
    out = self.decoder(out, encode_features)
    out = self.head(out)
    return out

# %%
NUM_CLASSES = 4
model = Unet(NUM_CLASSES)

# %% [markdown]
# #평가지표 정의하기

# %% [markdown]
# Dice similarity coefficient

# %% [markdown]
# Dice: (2 x (A*B) / (A + B))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Segmentation에서 F1 score과 비슷하다.
# F1 score이란 precision(정확도)과 recall(재현율)을 고려한
# 성능지표이다.

# %% [markdown]
# 1-dsc를 하면? dsc loss가 나온다.

# %%
class Unet_metric():
  def __init__(self, num_classes):
    self.num_classes = num_classes
    self.CE_loss = nn.CrossEntropyLoss(reduction = "mean") #detection, segmentation은 여러개의 element가 존재
    #2, 3차원이라서 mean을 사용

  def __call__(self, pred, target):
    onehot_pred = F.one_hot(torch.argmax(pred, dim = 1), num_classes = self.num_classes).permute(0, 3, 1, 2)
    onehot_target = F.one_hot(target, num_classes = self.num_classes).permute(0, 3, 1, 2)
    dice_coefficient = self.get_batch_dice_coefficient(onehot_pred, onehot_target)
    loss1 = self.get_dice_loss(onehot_pred, onehot_target)
    loss2 = self.CE_loss(pred, target)
    loss = loss1 + loss2
    return loss, dice_coefficient
  

  def get_dice_coefficient(self,  pred, target):
    dice = 0
    for class_idx in range(1, self.num_classes):
      A = pred[class_idx]
      B = target[class_idx]
      set_inter = torch.dot(A.reshape(-1).float(), B.reshape(-1).float())
      set_sum = A.sum() + B.sum()
      if set_sum.item()== 0:
        set_sum = 2 * set_inter
      dice += ((2 * set_inter) / (set_sum + 1e-8))
    dice /= (self.num_classes - 1)
    return dice

  def get_batch_dice_coefficient(self, pred, target):
    num_batch = pred.shape[0]
    dice = 0
    for batch_idx in range(num_batch):
      dice += self.get_dice_coefficient(pred[batch_idx], target[batch_idx])
    return dice / num_batch

  def get_dice_loss(self, pred, target):
    return 1. - self.get_batch_dice_coefficient(pred, target)

# %%
criterion = Unet_metric(num_classes = NUM_CLASSES)

# %% [markdown]
# Loss function 구현, SGDM최적화사용

# %% [markdown]
# 2개의 loss사용
# dice loss와 cross entropy loss를 사용

# %% [markdown]
# #학습과정

# %%
def train_one_epoch(dataloaders, model, criterion, optimizer, device):
  losses = {}
  dice_coefficients = {}
  
  for phase in ["train", "validation"]:
    running_loss = 0.0
    running_dice_coeff = 0.0

    if phase == "train":
      model.train()

    else:
      model.eval()

    for idx, data in enumerate(dataloaders[phase]):
      images = data[0].to(DEVICE)
      labels = data[1].to(DEVICE)
      with torch.set_grad_enabled(phase == "train"):
        predictions = model(images)
        loss, dice_coefficient = criterion(predictions, labels)

        if phase == "train":
          optimizer.zero_grad()
          loss.backward()
          optimizer.step()
        
        running_loss += loss.item()
        running_dice_coeff += dice_coefficient.item()

        if phase == "train":
          if idx > 0 and idx % 100 == 0:
            text = f"{idx}/{len(dataloaders['train'])}" +\
            f"-Running loss: {loss.item():.4f}" + \
            f"-Running dice: {dice_coefficient.item():4f}"
            print(text)

    losses[phase] = running_loss / len(dataloaders[phase])
    dice_coefficients[phase] = running_dice_coeff / len(dataloaders[phase])
  return losses, dice_coefficients

# %% [markdown]
# #기본 모델 훈련시키기

# %%
NUM_CLASSES = 4
IMAGE_SIZE = 224
BATCH_SIZE= 16
is_cuda = True
DEVICE = torch.device('cuda' if torch.cuda.is_available() and is_cuda else 'cpu')
print(DEVICE)
model = Unet(num_classes = NUM_CLASSES)
model = model.to(DEVICE)
criterion = Unet_metric(num_classes = NUM_CLASSES)
optimizer = torch.optim.SGD(model.parameters(), lr = 0.001, momentum = 0.9)
# Out:
# cuda

# %%
num_epochs = 30
best_epoch = 0
best_score = 0.0
train_loss, train_dice_coeff = [], []
val_loss, val_dice_coeff = [], []
for epoch in range(num_epochs):
  losses, dice_coefficients = train_one_epoch(dataloaders, model, criterion, optimizer, DEVICE)
  train_loss.append(losses["train"])
  val_loss.append(losses["validation"])
  train_dice_coeff.append(dice_coefficients["train"])
  val_dice_coeff.append(dice_coefficients["validation"])

  print(f"{epoch} / {num_epochs} - Train loss: {losses['train']:.4f}, Val loss: {losses['validation']:.4f}")
  print(f"{epoch} / {num_epochs} - Train{dice_coefficients['train']:.4f}, Val: {dice_coefficients['validation']:.4f}") #2시간 10분

# %%
#학습시간: 4시간
epoch = np.arange(30)
import csv
def save_result(epoch_, train_loss_, train_accuracy_, val_loss_, val_accuracy_, file_name):
  epoch_ = np.array(['epoch'] + list(epoch_))
  train_loss_ = np.array(['train_loss'] + list(train_loss_)) 
  train_accuracy_ = np.array(['train_accuracy'] + list(train_accuracy_))
  val_loss_ = np.array(['val_loss'] + list(val_loss_))
  val_accuracy_ = np.array(['val_accuracy']+ list(val_accuracy_))
  with open(file_name, 'w') as file:     #"model0.csv"
    writer = csv.writer(file)
    for i in range(len(epoch_)): 
      writer.writerow([epoch_[i], train_loss_[i],train_accuracy_[i],
                   val_loss_[i], val_accuracy_[i]])

# %%
save_result(epoch, train_loss, train_dice_coeff, val_loss, val_dice_coeff, "Original_Model.csv")

# %% [markdown]
# #모델1 정의

# %%
class Encoder(nn.Module):
  def __init__(self,):
    super().__init__()
    self.conv_block1 = Convlayer(in_channels = 3, out_channels = 32)
    self.conv_block2 = Convlayer(in_channels = 32, out_channels = 64)
    self.conv_block3 = Convlayer(in_channels = 64, out_channels = 128)
    self.conv_block4 = Convlayer(in_channels = 128, out_channels = 256)
    self.conv_block5 = Convlayer(in_channels = 256, out_channels = 512)
    self.pool = nn.MaxPool2d(kernel_size = 2)

  def forward(self, x):
    encode_features = []

    out = self.conv_block1(x)
    encode_features.append(out)
    out = self.pool(out)
  
    
    out = self.conv_block2(out)
    encode_features.append(out)
    out = self.pool(out)
    

    out = self.conv_block3(out)
    encode_features.append(out)
    out = self.pool(out)
    

    out = self.conv_block4(out)
    encode_features.append(out)
    out = self.pool(out)
    
  

    out = self.conv_block5(out)

    return out, encode_features

# %%
class Decoder(nn.Module):
  def __init__(self):
    super().__init__()
    self.upconv_layer1 = UpConvLayer(in_channels = 512, out_channels = 256)
    self.conv_block1 =  Convlayer(in_channels = 512, out_channels = 256)
    
    self.upconv_layer2 = UpConvLayer(in_channels = 256, out_channels = 128)
    self.conv_block2 =  Convlayer(in_channels = 256, out_channels = 128)

    self.upconv_layer3 = UpConvLayer(in_channels = 128, out_channels = 64)
    self.conv_block3 =  Convlayer(in_channels = 128, out_channels = 64)

    self.upconv_layer4 = UpConvLayer(in_channels = 64, out_channels = 32)
    self.conv_block4 =  Convlayer(in_channels = 64, out_channels = 32)
    

  def forward(self, x, encoder_features):
    out = self.upconv_layer1(x)
    out = torch.cat([out, encoder_features[-1]], dim = 1)
    out = self.conv_block1(out)

    out = self.upconv_layer2(out)
    out = torch.cat([out, encoder_features[-2]], dim = 1)
    out = self.conv_block2(out)

    out = self.upconv_layer3(out)
    out = torch.cat([out, encoder_features[-3]], dim = 1)
    out = self.conv_block3(out)
    
    out = self.upconv_layer4(out)
    out = torch.cat([out, encoder_features[-4]], dim = 1)
    out = self.conv_block4(out)

  

    return out

# %%
class Unet(nn.Module):
  def __init__(self, num_classes):
    super().__init__()
    self.encoder = Encoder()
    self.decoder = Decoder()
    self.head= nn.Conv2d(32, num_classes, kernel_size = 1, padding = 0)
  
  def forward(self, x):
    out, encode_features = self.encoder(x)
    out = self.decoder(out, encode_features)
    out = self.head(out)
    return out

# %%
NUM_CLASSES = 4
IMAGE_SIZE = 224
BATCH_SIZE= 16
is_cuda = True
DEVICE = torch.device('cuda' if torch.cuda.is_available() and is_cuda else 'cpu')
print(DEVICE)
model = Unet(num_classes = NUM_CLASSES)
model = model.to(DEVICE)
criterion = Unet_metric(num_classes = NUM_CLASSES)
optimizer = torch.optim.SGD(model.parameters(), lr = 0.001, momentum = 0.9)
# Out:
# cuda

# %%
num_epochs = 30
best_epoch = 0
best_score = 0.0
train_loss, train_dice_coeff = [], []
val_loss, val_dice_coeff = [], []
for epoch in range(num_epochs):
  losses, dice_coefficients = train_one_epoch(dataloaders, model, criterion, optimizer, DEVICE)
  train_loss.append(losses["train"])
  val_loss.append(losses["validation"])
  train_dice_coeff.append(dice_coefficients["train"])
  val_dice_coeff.append(dice_coefficients["validation"])

  print(f"{epoch} / {num_epochs} - Train loss: {losses['train']:.4f}, Val loss: {losses['validation']:.4f}")
  print(f"{epoch} / {num_epochs} - Train{dice_coefficients['train']:.4f}, Val: {dice_coefficients['validation']:.4f}")

# %%
epoch = np.arange(30)
import csv
def save_result(epoch_, train_loss_, train_accuracy_, val_loss_, val_accuracy_, file_name):
  epoch_ = np.array(['epoch'] + list(epoch_))
  train_loss_ = np.array(['train_loss'] + list(train_loss_)) 
  train_accuracy_ = np.array(['train_accuracy'] + list(train_accuracy_))
  val_loss_ = np.array(['val_loss'] + list(val_loss_))
  val_accuracy_ = np.array(['val_accuracy']+ list(val_accuracy_))
  with open(file_name, 'w') as file:     #"model0.csv"
    writer = csv.writer(file)
    for i in range(len(epoch_)): 
      writer.writerow([epoch_[i], train_loss_[i],train_accuracy_[i],
                   val_loss_[i], val_accuracy_[i]])

# %%
save_result(epoch, train_loss, train_dice_coeff, val_loss, val_dice_coeff, "Model1.csv")

# %% [markdown]
# #모델2 정의

# %%
class Encoder(nn.Module):
  def __init__(self,):
    super().__init__()
    self.conv_block1 = Convlayer(in_channels = 3, out_channels = 16)
    self.conv_block2 = Convlayer(in_channels = 16, out_channels = 32)
    self.conv_block3 = Convlayer(in_channels = 32, out_channels = 64)
    self.conv_block4 = Convlayer(in_channels = 64, out_channels = 128)
    self.conv_block5 = Convlayer(in_channels = 128, out_channels = 256)
    self.pool = nn.MaxPool2d(kernel_size = 2)

  def forward(self, x):
    encode_features = []

    out = self.conv_block1(x)
    encode_features.append(out)
    out = self.pool(out)
  
    
    out = self.conv_block2(out)
    encode_features.append(out)
    out = self.pool(out)
    

    out = self.conv_block3(out)
    encode_features.append(out)
    out = self.pool(out)
    

    out = self.conv_block4(out)
    encode_features.append(out)
    out = self.pool(out)
    
  

    out = self.conv_block5(out)

    return out, encode_features

# %%
class Decoder(nn.Module):
  def __init__(self):
    super().__init__()
    self.upconv_layer1 = UpConvLayer(in_channels = 256, out_channels = 128)
    self.conv_block1 =  Convlayer(in_channels = 256, out_channels = 128)
    
    self.upconv_layer2 = UpConvLayer(in_channels = 128, out_channels = 64)
    self.conv_block2 =  Convlayer(in_channels = 128, out_channels = 64)

    self.upconv_layer3 = UpConvLayer(in_channels = 64, out_channels = 32)
    self.conv_block3 =  Convlayer(in_channels = 64, out_channels = 32)

    self.upconv_layer4 = UpConvLayer(in_channels = 32, out_channels = 16)
    self.conv_block4 =  Convlayer(in_channels = 32, out_channels = 16)
    

  def forward(self, x, encoder_features):
    out = self.upconv_layer1(x)
    out = torch.cat([out, encoder_features[-1]], dim = 1)
    out = self.conv_block1(out)
    

    out = self.upconv_layer2(out)
    out = torch.cat([out, encoder_features[-2]], dim = 1)
    out = self.conv_block2(out)
    

    out = self.upconv_layer3(out)
    out = torch.cat([out, encoder_features[-3]], dim = 1)
    out = self.conv_block3(out)
    

    out = self.upconv_layer4(out)
    out = torch.cat([out, encoder_features[-4]], dim = 1)
    out = self.conv_block4(out)
  

    return out

# %%
class Unet(nn.Module):
  def __init__(self, num_classes):
    super().__init__()
    self.encoder = Encoder()
    self.decoder = Decoder()
    self.head= nn.Conv2d(16, num_classes, kernel_size = 1, padding = 0)
  
  def forward(self, x):
    out, encode_features = self.encoder(x)
    out = self.decoder(out, encode_features)
    out = self.head(out)
    return out

# %%
NUM_CLASSES = 4
IMAGE_SIZE = 224
BATCH_SIZE= 16
is_cuda = True
DEVICE = torch.device('cuda' if torch.cuda.is_available() and is_cuda else 'cpu')
print(DEVICE)
model = Unet(num_classes = NUM_CLASSES)
model = model.to(DEVICE)
criterion = Unet_metric(num_classes = NUM_CLASSES)
optimizer = torch.optim.SGD(model.parameters(), lr = 0.001, momentum = 0.9)

# %%
num_epochs = 30
best_epoch = 0
best_score = 0.0
train_loss, train_dice_coeff = [], []
val_loss, val_dice_coeff = [], []
for epoch in range(num_epochs):
  losses, dice_coefficients = train_one_epoch(dataloaders, model, criterion, optimizer, DEVICE)
  train_loss.append(losses["train"])
  val_loss.append(losses["validation"])
  train_dice_coeff.append(dice_coefficients["train"])
  val_dice_coeff.append(dice_coefficients["validation"])

  print(f"{epoch} / {num_epochs} - Train loss: {losses['train']:.4f}, Val loss: {losses['validation']:.4f}")
  print(f"{epoch} / {num_epochs} - Train{dice_coefficients['train']:.4f}, Val: {dice_coefficients['validation']:.4f}")

# %%
#2시간 17분
epoch = np.arange(30)
save_result(epoch, train_loss, train_dice_coeff, val_loss, val_dice_coeff, "Model2.csv")

# %% [markdown]
# #모델3: Spatial Attention 정의

# %%
def attention_block(mode = 'None', input_dim = None , r = None):
  if mode == 'spatial':
    return spatial_attention(input_dim)

  elif mode == 'channel':
    return channel_attention(input_dim, r)
  
  else:
    return nn.Sequential()

# %%
class spatial_attention(nn.Module):
  def __init__(self, in_channels):
    super().__init__()
    self.spatial = nn.Conv2d(in_channels, 1, kernel_size = 3, padding = 1)

  def forward(self, input):
    x = torch.sigmoid(self.spatial(input))
    return torch.mul(x, input)

# %%
class Encoder(nn.Module):
  def __init__(self,):
    super().__init__()
    self.conv_block1 = Convlayer(in_channels = 3, out_channels = 16)
    self.conv_block2 = Convlayer(in_channels = 16, out_channels = 32)
    self.conv_block3 = Convlayer(in_channels = 32, out_channels = 64)
    self.conv_block4 = Convlayer(in_channels = 64, out_channels = 128)
    self.attn1 = attention_block(mode = "Spatial", input_dim = 128, r = 64)
    self.conv_block5 = Convlayer(in_channels = 128, out_channels = 256)
    self.attn2 = attention_block(mode = "Spatial", input_dim = 256, r = 128)
    self.pool = nn.MaxPool2d(kernel_size = 2)

  def forward(self, x):
    encode_features = []

    out = self.conv_block1(x)
    encode_features.append(out)
    out = self.pool(out)
  
    
    out = self.conv_block2(out)
    encode_features.append(out)
    out = self.pool(out)
    

    out = self.conv_block3(out)
    encode_features.append(out)
    out = self.pool(out)
    
    

    out = self.conv_block4(out)
    encode_features.append(out)
    out = self.pool(out)
    out = self.attn1(out)
    
  

    out = self.conv_block5(out)
    out = self.attn2(out)

    return out, encode_features

# %%
class Decoder(nn.Module):
  def __init__(self):
    super().__init__()
    self.upconv_layer1 = UpConvLayer(in_channels = 256, out_channels = 128)
    self.conv_block1 =  Convlayer(in_channels = 256, out_channels = 128)
    
    self.upconv_layer2 = UpConvLayer(in_channels = 128, out_channels = 64)
    self.conv_block2 =  Convlayer(in_channels = 128, out_channels = 64)

    self.upconv_layer3 = UpConvLayer(in_channels = 64, out_channels = 32)
    self.conv_block3 =  Convlayer(in_channels = 64, out_channels = 32)

    self.upconv_layer4 = UpConvLayer(in_channels = 32, out_channels = 16)
    self.conv_block4 =  Convlayer(in_channels = 32, out_channels = 16)
    

  def forward(self, x, encoder_features):
    out = self.upconv_layer1(x)
    out = torch.cat([out, encoder_features[-1]], dim = 1)
    out = self.conv_block1(out)
    

    out = self.upconv_layer2(out)
    out = torch.cat([out, encoder_features[-2]], dim = 1)
    out = self.conv_block2(out)
    

    out = self.upconv_layer3(out)
    out = torch.cat([out, encoder_features[-3]], dim = 1)
    out = self.conv_block3(out)
    

    out = self.upconv_layer4(out)
    out = torch.cat([out, encoder_features[-4]], dim = 1)
    out = self.conv_block4(out)
  

    return out

# %%
class Unet(nn.Module):
  def __init__(self, num_classes):
    super().__init__()
    self.encoder = Encoder()
    self.decoder = Decoder()
    self.head= nn.Conv2d(16, num_classes, kernel_size = 1, padding = 0)
  
  def forward(self, x):
    out, encode_features = self.encoder(x)
    out = self.decoder(out, encode_features)
    out = self.head(out)
    return out

# %%
NUM_CLASSES = 4
IMAGE_SIZE = 224
BATCH_SIZE= 16
is_cuda = True
DEVICE = torch.device('cuda' if torch.cuda.is_available() and is_cuda else 'cpu')
print(DEVICE)
model = Unet(num_classes = NUM_CLASSES)
model = model.to(DEVICE)
criterion = Unet_metric(num_classes = NUM_CLASSES)
optimizer = torch.optim.SGD(model.parameters(), lr = 0.001, momentum = 0.9)
# Out:
# cuda

# %%
num_epochs = 30
best_epoch = 0
best_score = 0.0
train_loss, train_dice_coeff = [], []
val_loss, val_dice_coeff = [], []
for epoch in range(num_epochs):
  losses, dice_coefficients = train_one_epoch(dataloaders, model, criterion, optimizer, DEVICE)
  train_loss.append(losses["train"])
  val_loss.append(losses["validation"])
  train_dice_coeff.append(dice_coefficients["train"])
  val_dice_coeff.append(dice_coefficients["validation"])

  print(f"{epoch} / {num_epochs} - Train loss: {losses['train']:.4f}, Val loss: {losses['validation']:.4f}")
  print(f"{epoch} / {num_epochs} - Train{dice_coefficients['train']:.4f}, Val: {dice_coefficients['validation']:.4f}")

# %%
#2시간 19분
epoch = np.arange(30)
save_result(epoch, train_loss, train_dice_coeff, val_loss, val_dice_coeff, "Model3.csv")

# %% [markdown]
# #모델4 Channel Attention 정의

# %%
def attention_block(mode = 'None', input_dim = None , r = None):
  if mode == 'spatial':
    return spatial_attention(input_dim)

  elif mode == 'channel':
    return channel_attention(input_dim, r)
  
  else:
    return nn.Sequential()

# %%
class channel_attention(nn.Module):
  def __init__(self, in_channels, r = 16):
    super().__init__()
    self.avg = nn.AdaptiveAvgPool2d((1,1))
    self.excitation = nn.Sequential(
        nn.Linear(in_channels, r),
        nn.ReLU(),
        nn.Linear(r, in_channels),
        nn.Sigmoid()
        )
    
  def forward(self, input):
    x = self.avg(input) #x.size([batch_size, channel_size, 1, 1])
    x = x.view(x.size(0), -1) #x.size([batch_size, channel_size])
    x = self.excitation(x)
    x = x.view(x.size(0), x.size(1), 1, 1)
    return torch.mul(x, input)

# %%
class Encoder(nn.Module):
  def __init__(self,):
    super().__init__()
    self.conv_block1 = Convlayer(in_channels = 3, out_channels = 16)
    self.conv_block2 = Convlayer(in_channels = 16, out_channels = 32)
    self.conv_block3 = Convlayer(in_channels = 32, out_channels = 64)
    self.conv_block4 = Convlayer(in_channels = 64, out_channels = 128)
    self.attn1 = attention_block(mode = "Channel", input_dim = 128, r = 64)
    self.conv_block5 = Convlayer(in_channels = 128, out_channels = 256)
    self.attn2 = attention_block(mode = "Channel", input_dim = 256, r = 128)
    self.pool = nn.MaxPool2d(kernel_size = 2)

  def forward(self, x):
    encode_features = []

    out = self.conv_block1(x)
    encode_features.append(out)
    out = self.pool(out)
  
    
    out = self.conv_block2(out)
    encode_features.append(out)
    out = self.pool(out)
    

    out = self.conv_block3(out)
    encode_features.append(out)
    out = self.pool(out)
    
    

    out = self.conv_block4(out)
    encode_features.append(out)
    out = self.pool(out)
    out = self.attn1(out)
    
  

    out = self.conv_block5(out)
    out = self.attn2(out)

    return out, encode_features

# %%
class Decoder(nn.Module):
  def __init__(self):
    super().__init__()
    self.upconv_layer1 = UpConvLayer(in_channels = 256, out_channels = 128)
    self.conv_block1 =  Convlayer(in_channels = 256, out_channels = 128)
    
    self.upconv_layer2 = UpConvLayer(in_channels = 128, out_channels = 64)
    self.conv_block2 =  Convlayer(in_channels = 128, out_channels = 64)

    self.upconv_layer3 = UpConvLayer(in_channels = 64, out_channels = 32)
    self.conv_block3 =  Convlayer(in_channels = 64, out_channels = 32)

    self.upconv_layer4 = UpConvLayer(in_channels = 32, out_channels = 16)
    self.conv_block4 =  Convlayer(in_channels = 32, out_channels = 16)
    

  def forward(self, x, encoder_features):
    out = self.upconv_layer1(x)
    out = torch.cat([out, encoder_features[-1]], dim = 1)
    out = self.conv_block1(out)
    

    out = self.upconv_layer2(out)
    out = torch.cat([out, encoder_features[-2]], dim = 1)
    out = self.conv_block2(out)
    

    out = self.upconv_layer3(out)
    out = torch.cat([out, encoder_features[-3]], dim = 1)
    out = self.conv_block3(out)
    

    out = self.upconv_layer4(out)
    out = torch.cat([out, encoder_features[-4]], dim = 1)
    out = self.conv_block4(out)
  

    return out

# %%
class Unet(nn.Module):
  def __init__(self, num_classes):
    super().__init__()
    self.encoder = Encoder()
    self.decoder = Decoder()
    self.head= nn.Conv2d(16, num_classes, kernel_size = 1, padding = 0)
  
  def forward(self, x):
    out, encode_features = self.encoder(x)
    out = self.decoder(out, encode_features)
    out = self.head(out)
    return out

# %%
NUM_CLASSES = 4
IMAGE_SIZE = 224
BATCH_SIZE= 16
is_cuda = True
DEVICE = torch.device('cuda' if torch.cuda.is_available() and is_cuda else 'cpu')
print(DEVICE)
model = Unet(num_classes = NUM_CLASSES)
model = model.to(DEVICE)
criterion = Unet_metric(num_classes = NUM_CLASSES)
optimizer = torch.optim.SGD(model.parameters(), lr = 0.001, momentum = 0.9)

# %%
num_epochs = 30
best_epoch = 0
best_score = 0.0
train_loss, train_dice_coeff = [], []
val_loss, val_dice_coeff = [], []
for epoch in range(num_epochs):
  losses, dice_coefficients = train_one_epoch(dataloaders, model, criterion, optimizer, DEVICE)
  train_loss.append(losses["train"])
  val_loss.append(losses["validation"])
  train_dice_coeff.append(dice_coefficients["train"])
  val_dice_coeff.append(dice_coefficients["validation"])

  print(f"{epoch} / {num_epochs} - Train loss: {losses['train']:.4f}, Val loss: {losses['validation']:.4f}")
  print(f"{epoch} / {num_epochs} - Train{dice_coefficients['train']:.4f}, Val: {dice_coefficients['validation']:.4f}")

# %%
#2시간 32분
epoch = np.arange(30)
save_result(epoch, train_loss, train_dice_coeff, val_loss, val_dice_coeff, "Model4.csv")

# %% [markdown]
# #미리학습된 모델

# %%
import segmentation_models_pytorch as smp

# %%
def UnetResNext():
    return smp.Unet(
        encoder_name='se_resnext50_32x4d',
        encoder_weights='imagenet',
        in_channels=3,
        classes=4
    )

# %%
model1 = UnetResNext()
NUM_CLASSES = 4
IMAGE_SIZE = 224
BATCH_SIZE= 16
is_cuda = True
DEVICE = torch.device('cuda' if torch.cuda.is_available() and is_cuda else 'cpu')
print(DEVICE)
model1 = model1.to(DEVICE)
criterion = Unet_metric(num_classes = NUM_CLASSES)
optimizer = torch.optim.SGD(model1.parameters(), lr = 0.001, momentum = 0.9)
# Out:
# Downloading: "http://data.lip6.fr/cadene/pretrainedmodels/se_resnext50_32x4d-a260b3a4.pth" to /root/.cache/torch/hub/checkpoints/se_resnext50_32x4d-a260b3a4.pth
#   0%|          | 0.00/105M [00:00<?, ?B/s]
# cuda

# %%
num_epochs = 30
best_epoch = 0
best_score = 0.0
train_loss, train_dice_coeff = [], []
val_loss, val_dice_coeff = [], []
for epoch in range(num_epochs):
  losses, dice_coefficients = train_one_epoch(dataloaders, model1, criterion, optimizer, DEVICE)
  train_loss.append(losses["train"])
  val_loss.append(losses["validation"])
  train_dice_coeff.append(dice_coefficients["train"])
  val_dice_coeff.append(dice_coefficients["validation"])

  print(f"{epoch} / {num_epochs} - Train loss: {losses['train']:.4f}, Val loss: {losses['validation']:.4f}")
  print(f"{epoch} / {num_epochs} - Train{dice_coefficients['train']:.4f}, Val: {dice_coefficients['validation']:.4f}")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# 100/813-Running loss: 1.0789-Running dice: 0.000000
# 200/813-Running loss: 1.6830-Running dice: 0.015271
# 300/813-Running loss: 1.4352-Running dice: 0.198957
# 400/813-Running loss: 0.9763-Running dice: 0.109479
# 500/813-Running loss: 0.8662-Running dice: 0.301053
# 600/813-Running loss: 0.8045-Running dice: 0.311504
# 700/813-Running loss: 0.8069-Running dice: 0.315224
# 800/813-Running loss: 0.8758-Running dice: 0.312874
# 0 / 30 - Train loss: 1.0883, Val loss: 1.0441
# 0 / 30 - Train0.1378, Val: 0.1722
# 100/813-Running loss: 1.0370-Running dice: 0.000000
# 200/813-Running loss: 0.9990-Running dice: 0.321987
# 300/813-Running loss: 1.3641-Running dice: 0.230258
# 400/813-Running loss: 0.8924-Running dice: 0.153948
# 500/813-Running loss: 0.7933-Running dice: 0.316613
# 600/813-Running loss: 0.7335-Running dice: 0.325915
# 700/813-Running loss: 0.7469-Running dice: 0.324823
# 800/813-Running loss: 0.8199-Running dice: 0.314979
# 1 / 30 - Train loss: 0.9328, Val loss: 1.0024
# 1 / 30 - Train0.1953, Val: 0.1859
# 100/813-Running loss: 1.0313-Running dice: 0.000000
# 200/813-Running loss: 0.8972-Running dice: 0.325769
# 300/813-Running loss: 1.3348-Running dice: 0.233799
# 400/813-Running loss: 0.8643-Running dice: 0.171344
# 500/813-Running loss: 0.7728-Running dice: 0.320785
# 600/813-Running loss: 0.7207-Running dice: 0.327780
# 700/813-Running loss: 0.7334-Running dice: 0.325930
# 800/813-Running loss: 0.7869-Running dice: 0.316607
# 2 / 30 - Train loss: 0.9101, Val loss: 0.9844
# 2 / 30 - Train0.2007, Val: 0.1869
# 100/813-Running loss: 1.0283-Running dice: 0.000000
# 200/813-Running loss: 0.8440-Running dice: 0.326589
# 300/813-Running loss: 1.2896-Running dice: 0.235602
# 400/813-Running loss: 0.8574-Running dice: 0.172605
# 500/813-Running loss: 0.7675-Running dice: 0.321771
# 600/813-Running loss: 0.7149-Running dice: 0.328134
# 700/813-Running loss: 0.7273-Running dice: 0.326236
# 800/813-Running loss: 0.7065-Running dice: 0.377095
# 3 / 30 - Train loss: 0.8953, Val loss: 0.9717
# 3 / 30 - Train0.2052, Val: 0.1905
# 100/813-Running loss: 1.0267-Running dice: 0.000000
# 200/813-Running loss: 0.8005-Running dice: 0.341802
# 300/813-Running loss: 1.2589-Running dice: 0.237425
# 400/813-Running loss: 0.8608-Running dice: 0.165988
# 500/813-Running loss: 0.7655-Running dice: 0.322372
# 600/813-Running loss: 0.7105-Running dice: 0.328259
# 700/813-Running loss: 0.6893-Running dice: 0.360262
# 800/813-Running loss: 0.6015-Running dice: 0.467845
# 4 / 30 - Train loss: 0.8763, Val loss: 0.9619
# 4 / 30 - Train0.2165, Val: 0.1988
# 100/813-Running loss: 1.0264-Running dice: 0.000000
# 200/813-Running loss: 0.5749-Running dice: 0.546425
# 300/813-Running loss: 1.2199-Running dice: 0.244754
# 400/813-Running loss: 0.8614-Running dice: 0.163079
# 500/813-Running loss: 0.7585-Running dice: 0.327872
# 600/813-Running loss: 0.7072-Running dice: 0.328354
# 700/813-Running loss: 0.6488-Running dice: 0.397615
# 800/813-Running loss: 0.5593-Running dice: 0.499676
# 5 / 30 - Train loss: 0.8575, Val loss: 0.9631
# 5 / 30 - Train0.2285, Val: 0.2026
# 100/813-Running loss: 1.0260-Running dice: 0.000000
# 200/813-Running loss: 0.5144-Running dice: 0.592617
# 300/813-Running loss: 1.1539-Running dice: 0.269631
# 400/813-Running loss: 0.8633-Running dice: 0.159561
# 500/813-Running loss: 0.7512-Running dice: 0.331653
# 600/813-Running loss: 0.7051-Running dice: 0.328315
# 700/813-Running loss: 0.6399-Running dice: 0.403062
# 800/813-Running loss: 0.5338-Running dice: 0.517195
# 6 / 30 - Train loss: 0.8401, Val loss: 0.9671
# 6 / 30 - Train0.2397, Val: 0.2039
# 100/813-Running loss: 1.0254-Running dice: 0.000000
# 200/813-Running loss: 0.4984-Running dice: 0.600613
# 300/813-Running loss: 1.0563-Running dice: 0.319691
# 400/813-Running loss: 0.8645-Running dice: 0.156394
# 500/813-Running loss: 0.7477-Running dice: 0.329100
# 600/813-Running loss: 0.7032-Running dice: 0.328305
# 700/813-Running loss: 0.6380-Running dice: 0.402491
# 800/813-Running loss: 0.5208-Running dice: 0.524579
# 7 / 30 - Train loss: 0.8291, Val loss: 0.9713
# 7 / 30 - Train0.2454, Val: 0.2033
# 100/813-Running loss: 1.0247-Running dice: 0.000000
# 200/813-Running loss: 0.5559-Running dice: 0.568017
# 300/813-Running loss: 1.0055-Running dice: 0.343402
# 400/813-Running loss: 0.8640-Running dice: 0.155731
# 500/813-Running loss: 0.7437-Running dice: 0.330872
# 600/813-Running loss: 0.7026-Running dice: 0.328279
# 700/813-Running loss: 0.6272-Running dice: 0.410704
# 800/813-Running loss: 0.5095-Running dice: 0.530834
# 8 / 30 - Train loss: 0.8201, Val loss: 0.9609
# 8 / 30 - Train0.2502, Val: 0.2085
# 100/813-Running loss: 1.0245-Running dice: 0.000000
# 200/813-Running loss: 0.4464-Running dice: 0.625688
# 300/813-Running loss: 0.9211-Running dice: 0.392725
# 400/813-Running loss: 0.8736-Running dice: 0.144467
# 500/813-Running loss: 0.7412-Running dice: 0.324656
# 600/813-Running loss: 0.7012-Running dice: 0.328234
# 700/813-Running loss: 0.6264-Running dice: 0.409825
# 800/813-Running loss: 0.5088-Running dice: 0.530065
# 9 / 30 - Train loss: 0.8136, Val loss: 0.9604
# 9 / 30 - Train0.2530, Val: 0.2098
# 100/813-Running loss: 1.0230-Running dice: 0.000000
# 200/813-Running loss: 0.4507-Running dice: 0.621003
# 300/813-Running loss: 0.7979-Running dice: 0.454748
# 400/813-Running loss: 0.8638-Running dice: 0.153129
# 500/813-Running loss: 0.7347-Running dice: 0.324453
# 600/813-Running loss: 0.6984-Running dice: 0.328321
# 700/813-Running loss: 0.6157-Running dice: 0.418956
# 800/813-Running loss: 0.4994-Running dice: 0.535327
# 10 / 30 - Train loss: 0.8011, Val loss: 0.9626
# 10 / 30 - Train0.2582, Val: 0.2100
# 100/813-Running loss: 1.0214-Running dice: 0.000000
# 200/813-Running loss: 0.4288-Running dice: 0.630233
# 300/813-Running loss: 0.7036-Running dice: 0.511689
# 400/813-Running loss: 0.8665-Running dice: 0.148580
# 500/813-Running loss: 0.7305-Running dice: 0.325157
# 600/813-Running loss: 0.6963-Running dice: 0.328307
# 700/813-Running loss: 0.6125-Running dice: 0.421301
# 800/813-Running loss: 0.4957-Running dice: 0.536090
# 11 / 30 - Train loss: 0.7907, Val loss: 0.9661
# 11 / 30 - Train0.2614, Val: 0.2105
# 100/813-Running loss: 1.0203-Running dice: 0.000000
# 200/813-Running loss: 0.4107-Running dice: 0.637353
# 300/813-Running loss: 0.6530-Running dice: 0.539954
# 400/813-Running loss: 0.8542-Running dice: 0.159591
# 500/813-Running loss: 0.7266-Running dice: 0.326383
# 600/813-Running loss: 0.6942-Running dice: 0.328548
# 700/813-Running loss: 0.6298-Running dice: 0.403484
# 800/813-Running loss: 0.4903-Running dice: 0.538426
# 12 / 30 - Train loss: 0.7814, Val loss: 0.9606
# 12 / 30 - Train0.2647, Val: 0.2143
# 100/813-Running loss: 1.0198-Running dice: 0.000000
# 200/813-Running loss: 0.4167-Running dice: 0.633076
# 300/813-Running loss: 0.6075-Running dice: 0.561280
# 400/813-Running loss: 0.8602-Running dice: 0.152914
# 500/813-Running loss: 0.7251-Running dice: 0.325474
# 600/813-Running loss: 0.6925-Running dice: 0.328833
# 700/813-Running loss: 0.6079-Running dice: 0.422449
# 800/813-Running loss: 0.4890-Running dice: 0.538310
# 13 / 30 - Train loss: 0.7749, Val loss: 0.9623
# 13 / 30 - Train0.2667, Val: 0.2159
# 100/813-Running loss: 1.0187-Running dice: 0.000000
# 200/813-Running loss: 0.3943-Running dice: 0.644374
# 300/813-Running loss: 0.5781-Running dice: 0.572181
# 400/813-Running loss: 0.8573-Running dice: 0.155344
# 500/813-Running loss: 0.7187-Running dice: 0.329965
# 600/813-Running loss: 0.6916-Running dice: 0.328957
# 700/813-Running loss: 0.6362-Running dice: 0.397114
# 800/813-Running loss: 0.4871-Running dice: 0.538957
# 14 / 30 - Train loss: 0.7689, Val loss: 0.9638
# 14 / 30 - Train0.2695, Val: 0.2178
# 100/813-Running loss: 1.0189-Running dice: 0.000000
# 200/813-Running loss: 0.3853-Running dice: 0.647905
# 300/813-Running loss: 0.5467-Running dice: 0.584495
# 400/813-Running loss: 0.8432-Running dice: 0.169591
# 500/813-Running loss: 0.7099-Running dice: 0.337094
# 600/813-Running loss: 0.6903-Running dice: 0.329163
# 700/813-Running loss: 0.6099-Running dice: 0.419817
# 800/813-Running loss: 0.4834-Running dice: 0.541579
# 15 / 30 - Train loss: 0.7653, Val loss: 0.9562
# 15 / 30 - Train0.2705, Val: 0.2226
# 100/813-Running loss: 1.0174-Running dice: 0.000000
# 200/813-Running loss: 0.3802-Running dice: 0.650090
# 300/813-Running loss: 0.5342-Running dice: 0.592163
# 400/813-Running loss: 0.8764-Running dice: 0.136275
# 500/813-Running loss: 0.7107-Running dice: 0.335187
# 600/813-Running loss: 0.6890-Running dice: 0.329449
# 700/813-Running loss: 0.6011-Running dice: 0.425799
# 800/813-Running loss: 0.4835-Running dice: 0.540530
# 16 / 30 - Train loss: 0.7604, Val loss: 0.9588
# 16 / 30 - Train0.2730, Val: 0.2245
# 100/813-Running loss: 1.0173-Running dice: 0.000000
# 200/813-Running loss: 0.3771-Running dice: 0.651115
# 300/813-Running loss: 0.5186-Running dice: 0.597187
# 400/813-Running loss: 0.8386-Running dice: 0.174089
# 500/813-Running loss: 0.7192-Running dice: 0.326366
# 600/813-Running loss: 0.6885-Running dice: 0.329704
# 700/813-Running loss: 0.5971-Running dice: 0.429446
# 800/813-Running loss: 0.4761-Running dice: 0.546599
# 17 / 30 - Train loss: 0.7568, Val loss: 0.9613
# 17 / 30 - Train0.2746, Val: 0.2254
# 100/813-Running loss: 1.0160-Running dice: 0.000000
# 200/813-Running loss: 0.3745-Running dice: 0.652031
# 300/813-Running loss: 0.5068-Running dice: 0.602193
# 400/813-Running loss: 0.8505-Running dice: 0.161941
# 500/813-Running loss: 0.6978-Running dice: 0.345093
# 600/813-Running loss: 0.6877-Running dice: 0.329825
# 700/813-Running loss: 0.5943-Running dice: 0.431342
# 800/813-Running loss: 0.4773-Running dice: 0.545478
# 18 / 30 - Train loss: 0.7537, Val loss: 0.9634
# 18 / 30 - Train0.2762, Val: 0.2276
# 100/813-Running loss: 1.0148-Running dice: 0.000000
# 200/813-Running loss: 0.3724-Running dice: 0.652718
# 300/813-Running loss: 0.4906-Running dice: 0.608485
# 400/813-Running loss: 0.8411-Running dice: 0.169213
# 500/813-Running loss: 0.7038-Running dice: 0.337572
# 600/813-Running loss: 0.6872-Running dice: 0.329957
# 700/813-Running loss: 0.6013-Running dice: 0.424025
# 800/813-Running loss: 0.4741-Running dice: 0.547402
# 19 / 30 - Train loss: 0.7499, Val loss: 0.9629
# 19 / 30 - Train0.2781, Val: 0.2282
# 100/813-Running loss: 1.0138-Running dice: 0.000000
# 200/813-Running loss: 0.3710-Running dice: 0.653158
# 300/813-Running loss: 0.4841-Running dice: 0.611297
# 400/813-Running loss: 0.8324-Running dice: 0.178069
# 500/813-Running loss: 0.7032-Running dice: 0.337547
# 600/813-Running loss: 0.6867-Running dice: 0.330069
# 700/813-Running loss: 0.5940-Running dice: 0.431657
# 800/813-Running loss: 0.4752-Running dice: 0.548326
# 20 / 30 - Train loss: 0.7470, Val loss: 0.9623
# 20 / 30 - Train0.2796, Val: 0.2308
# 100/813-Running loss: 1.0142-Running dice: 0.000000
# 200/813-Running loss: 0.3696-Running dice: 0.653553
# 300/813-Running loss: 0.4884-Running dice: 0.609530
# 400/813-Running loss: 0.8389-Running dice: 0.171423
# 500/813-Running loss: 0.6840-Running dice: 0.355527
# 600/813-Running loss: 0.6865-Running dice: 0.330189
# 700/813-Running loss: 0.5913-Running dice: 0.433139
# 800/813-Running loss: 0.4763-Running dice: 0.545902
# 21 / 30 - Train loss: 0.7444, Val loss: 0.9583
# 21 / 30 - Train0.2809, Val: 0.2342
# 100/813-Running loss: 1.0133-Running dice: 0.000000
# 200/813-Running loss: 0.3682-Running dice: 0.654132
# 300/813-Running loss: 0.4735-Running dice: 0.616039
# 400/813-Running loss: 0.8313-Running dice: 0.177838
# 500/813-Running loss: 0.7020-Running dice: 0.336626
# 600/813-Running loss: 0.6862-Running dice: 0.330209
# 700/813-Running loss: 0.6067-Running dice: 0.418327
# 800/813-Running loss: 0.4738-Running dice: 0.548173
# 22 / 30 - Train loss: 0.7416, Val loss: 0.9599
# 22 / 30 - Train0.2825, Val: 0.2351
# 100/813-Running loss: 1.0123-Running dice: 0.000000
# 200/813-Running loss: 0.3672-Running dice: 0.654418
# 300/813-Running loss: 0.4680-Running dice: 0.617718
# 400/813-Running loss: 0.8151-Running dice: 0.193609
# 500/813-Running loss: 0.6790-Running dice: 0.358905
# 600/813-Running loss: 0.6857-Running dice: 0.330326
# 700/813-Running loss: 0.5909-Running dice: 0.433312
# 800/813-Running loss: 0.4652-Running dice: 0.554545
# 23 / 30 - Train loss: 0.7391, Val loss: 0.9541
# 23 / 30 - Train0.2838, Val: 0.2387
# 100/813-Running loss: 1.0116-Running dice: 0.000000
# 200/813-Running loss: 0.3660-Running dice: 0.654937
# 300/813-Running loss: 0.4778-Running dice: 0.612580
# 400/813-Running loss: 0.8241-Running dice: 0.184303
# 500/813-Running loss: 0.6964-Running dice: 0.341302
# 600/813-Running loss: 0.6856-Running dice: 0.330356
# 700/813-Running loss: 0.5886-Running dice: 0.434301
# 800/813-Running loss: 0.4676-Running dice: 0.551861
# 24 / 30 - Train loss: 0.7365, Val loss: 0.9589
# 24 / 30 - Train0.2854, Val: 0.2379
# 100/813-Running loss: 1.0112-Running dice: 0.000000
# 200/813-Running loss: 0.3655-Running dice: 0.655101
# 300/813-Running loss: 0.4640-Running dice: 0.619403
# 400/813-Running loss: 0.8084-Running dice: 0.199771
# 500/813-Running loss: 0.6999-Running dice: 0.336890
# 600/813-Running loss: 0.6852-Running dice: 0.330424
# 700/813-Running loss: 0.5881-Running dice: 0.434534
# 800/813-Running loss: 0.4680-Running dice: 0.550827
# 25 / 30 - Train loss: 0.7351, Val loss: 0.9584
# 25 / 30 - Train0.2861, Val: 0.2393
# 100/813-Running loss: 1.0107-Running dice: 0.000000
# 200/813-Running loss: 0.3654-Running dice: 0.654917
# 300/813-Running loss: 0.4530-Running dice: 0.623615
# 400/813-Running loss: 0.8087-Running dice: 0.199217
# 500/813-Running loss: 0.6864-Running dice: 0.349787
# 600/813-Running loss: 0.6851-Running dice: 0.330405
# 700/813-Running loss: 0.5903-Running dice: 0.432681
# 800/813-Running loss: 0.4616-Running dice: 0.557145
# 26 / 30 - Train loss: 0.7332, Val loss: 0.9643
# 26 / 30 - Train0.2872, Val: 0.2363
# 100/813-Running loss: 1.0103-Running dice: 0.000000
# 200/813-Running loss: 0.3647-Running dice: 0.655234
# 300/813-Running loss: 0.4563-Running dice: 0.621388
# 400/813-Running loss: 0.8135-Running dice: 0.194456
# 500/813-Running loss: 0.6948-Running dice: 0.340902
# 600/813-Running loss: 0.6848-Running dice: 0.330477
# 700/813-Running loss: 0.5901-Running dice: 0.432429
# 800/813-Running loss: 0.4605-Running dice: 0.557466
# 27 / 30 - Train loss: 0.7323, Val loss: 0.9678
# 27 / 30 - Train0.2876, Val: 0.2363
# 100/813-Running loss: 1.0099-Running dice: 0.000000
# 200/813-Running loss: 0.3647-Running dice: 0.655054
# 300/813-Running loss: 0.4416-Running dice: 0.627564
# 400/813-Running loss: 0.8066-Running dice: 0.200809
# 500/813-Running loss: 0.6918-Running dice: 0.342482
# 600/813-Running loss: 0.6846-Running dice: 0.330518
# 700/813-Running loss: 0.5874-Running dice: 0.435132
# 800/813-Running loss: 0.4688-Running dice: 0.549287
# 28 / 30 - Train loss: 0.7307, Val loss: 0.9645
# 28 / 30 - Train0.2885, Val: 0.2386
# 100/813-Running loss: 1.0097-Running dice: 0.000000
# 200/813-Running loss: 0.3632-Running dice: 0.655744
# 300/813-Running loss: 0.4374-Running dice: 0.629417
# 400/813-Running loss: 0.8166-Running dice: 0.191300
# 500/813-Running loss: 0.6778-Running dice: 0.356037
# 600/813-Running loss: 0.6846-Running dice: 0.330484
# 700/813-Running loss: 0.6022-Running dice: 0.420656
# 800/813-Running loss: 0.4597-Running dice: 0.558446
# 29 / 30 - Train loss: 0.7288, Val loss: 0.9745
# 29 / 30 - Train0.2896, Val: 0.2352

# %% [markdown]
# #결과확인

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
def plot_result(_df):
  plt.figure(figsize = (13, 13))
  fig1 = plt.subplot(3, 2, 1)
  fig1.plot(_df['epoch'], _df['train_loss'])
  fig1.grid()
  fig1.set_title('Train Loss')

  fig2 = plt.subplot(3, 2, 2)
  fig2.plot(_df['epoch'], _df['train_accuracy'])
  fig2.grid()
  fig2.set_title('Train Accuracy')

  fig3 = plt.subplot(3, 2, 3)
  fig3.plot(_df['epoch'], _df['val_loss'], color = 'orange')
  fig3.grid()
  fig3.set_title('Validation Loss')

  fig4 = plt.subplot(3, 2, 4)
  fig4.plot(_df['epoch'], _df['val_accuracy'], color = 'orange')
  fig4.grid()
  fig4.set_title('Validation Accuracy')

  fig5 = plt.subplot(3, 2, 5)
  fig5.plot(_df['epoch'], _df['train_loss'], label = 'Train Loss')
  fig5.plot(_df['epoch'], _df['val_loss'], color = 'orange', label = 'Vaidation Loss')
  fig5.grid()
  fig5.set_title('Train & Validation Loss')
  fig5.legend(loc ='upper right')

  fig6 = plt.subplot(3, 2, 6)
  fig6.legend(loc ='upper right')
  fig6.plot(_df['epoch'], _df['train_accuracy'], label = 'Train Accuracy')
  fig6.plot(_df['epoch'], _df['val_accuracy'], color = 'orange', label = 'Vaidation Accuracy')
  fig6.grid()
  fig6.set_title('Train & Validation Accuracy')
  fig6.legend(loc ='lower right')

# %%
Original_df = pd.read_csv('/content/Original_Model.csv')
model1_df = pd.read_csv('/content/Model1.csv')
model2_df = pd.read_csv('/content/Model2.csv')
model3_df = pd.read_csv('/content/Model3.csv')
model4_df = pd.read_csv('/content/Model4.csv')

# %%
plot_result(Original_df)
# Out:
# No handles with labels found to put in legend.

# %%
plot_result(model1_df)
# Out:
# No handles with labels found to put in legend.

# %%
plot_result(model2_df)
# Out:
# No handles with labels found to put in legend.

# %%
plot_result(model3_df)
# Out:
# No handles with labels found to put in legend.

# %%
plot_result(model4_df)
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(Original_df['train_loss'], label = 'Original')
plt.plot(model1_df['epoch'],model1_df['train_loss'], label = 'Half')
plt.plot(model2_df['epoch'],model2_df['train_loss'], label = 'Quarter')
plt.plot(model3_df['epoch'],model3_df['train_loss'], label = 'Quarter_Sa')
plt.plot(model4_df['epoch'],model4_df['train_loss'], label = 'Serial_Ca')
plt.legend(loc = 'upper right')
plt.grid()
plt.title('train_loss')
# Out:
# Text(0.5, 1.0, 'train_loss')

# %%
plt.plot(Original_df['train_accuracy'], label = 'Original')
plt.plot(model1_df['epoch'],model1_df['train_accuracy'], label = 'Half')
plt.plot(model2_df['epoch'],model2_df['train_accuracy'], label = 'Quarter')
plt.plot(model3_df['epoch'],model3_df['train_accuracy'], label = 'Quarter_Sa')
plt.plot(model4_df['epoch'],model4_df['train_accuracy'], label = 'Quarter_Ca')
plt.legend(loc = 'lower right')
plt.grid()
plt.title('train_dice_coefficient')
# Out:
# Text(0.5, 1.0, 'train_dice_coefficient')

# %%
plt.plot(Original_df['val_loss'], label = 'Original')
plt.plot(model1_df['epoch'],model1_df['val_loss'], label = 'Half')
plt.plot(model2_df['epoch'],model2_df['val_loss'], label = 'Quarter')
plt.plot(model3_df['epoch'],model3_df['val_loss'], label = 'Quarter_Sa')
plt.plot(model4_df['epoch'],model4_df['val_loss'], label = 'Quarter_Ca')
plt.legend(loc = 'upper right')
plt.grid()
plt.title('validation_loss')
# Out:
# Text(0.5, 1.0, 'validation_loss')

# %%
plt.plot(Original_df['val_accuracy'], label = 'Original')
plt.plot(model1_df['epoch'],model1_df['val_accuracy'], label = 'Half')
plt.plot(model2_df['epoch'],model2_df['val_accuracy'], label = 'Quarter')
plt.plot(model3_df['epoch'],model3_df['val_accuracy'], label = 'Quarter_Sa')
plt.plot(model4_df['epoch'],model4_df['val_accuracy'], label = 'Quarter_Ca')
plt.legend(loc = 'lower right')
plt.grid()
plt.title('validation_dice_coefficient')
# Out:
# Text(0.5, 1.0, 'validation_dice_coefficient')

# %%
train_loss_min = [min(Original_df['train_loss']), min(model1_df['train_loss']), min(model2_df['train_loss']), min(model3_df['train_loss']), min(model4_df['train_loss'])]
for i in range(len(train_loss_min)):
  print(train_loss_min[i])
# Out:
# 0.6292018545619676
# 0.7471477443588322
# 0.7609052460498622
# 0.769813802739351
# 0.7681632057327186

# %%
train_loss_min_idx = train_loss_min.index(min(train_loss_min))
print(f"model{train_loss_min_idx}가 가장 낮은 훈련 loss를 가짐")
# Out:
# model0가 가장 낮은 훈련 loss를 가짐

# %%
train_accuracy_max = [max(Original_df['train_accuracy']), max(model1_df['train_accuracy']), max(model2_df['train_accuracy']), max(model3_df['train_accuracy']), max(model4_df['train_accuracy'])]

# %%
train_accuracy_max_idx = train_accuracy_max.index(max(train_accuracy_max))
print(f"model{train_accuracy_max_idx}가 가장 높은 훈련 정확도를 가짐")
# Out:
# model0가 가장 높은 훈련 정확도를 가짐

# %%
val_loss_min = [min(Original_df['val_loss']), min(model1_df['val_loss']), min(model2_df['val_loss']), min(model3_df['val_loss']), min(model4_df['val_loss'])]

# %%
val_loss_min_idx = val_loss_min.index(min(val_loss_min))
print(f"model{val_loss_min_idx}가 가장 낮은 검증 loss를 가짐")
# Out:
# model0가 가장 낮은 검증 loss를 가짐

# %%
val_accuracy_max = [max(Original_df['train_accuracy']), max(model1_df['val_accuracy']), max(model2_df['val_accuracy']), max(model3_df['val_accuracy']), max(model4_df['val_accuracy'])]
for i in range(len(val_accuracy_max)):
  print(val_accuracy_max[i])
# Out:
# 0.3909138994746633
# 0.2116175879754619
# 0.2030231785556052
# 0.2259952710210827
# 0.2175402834245922

# %%
val_accuracy_max_idx = val_accuracy_max.index(max(val_accuracy_max))
print(f"model{val_accuracy_max_idx}이 가장 높은 검증 정확도를 가짐")
# Out:
# model0이 가장 높은 검증 정확도를 가짐

# %%
image, target = train_set[19]
image = np.array(image)
image = np.expand_dims(image, 0)
image = torch.Tensor(image)

# %%
image = image.to(DEVICE)
predicted = model(image)

# %%
plt.imshow(image[0].permute(1, 2, 0).cpu().numpy().astype(np.uint8))

# %%
plt.imshow(predicted[0].permute(1, 2, 0).detach().cpu().numpy().astype(np.uint8))
plt.show()

# %%
image, target = train_set[790]
image = np.array(image)
image = np.expand_dims(image, 0)
image = torch.Tensor(image)
image = image.to(DEVICE)
predicted = model(image)
plt.imshow(predicted[0].permute(1, 2, 0).detach().cpu().numpy().astype(np.uint8))
plt.show()

# %%
plt.imshow(image[0].permute(1, 2, 0).cpu().numpy().astype(np.uint8))

# %%
image, target = train_set[3184]
image = np.array(image)
image = np.expand_dims(image, 0)
image = torch.Tensor(image)
image = image.to(DEVICE)
predicted = model(image)
plt.imshow(predicted[0].permute(1, 2, 0).detach().cpu().numpy().astype(np.uint8))
plt.show()

# %%
plt.imshow(image[0].permute(1, 2, 0).cpu().numpy().astype(np.uint8))

# %%
image, target = train_set[3190]
image = np.array(image)
image = np.expand_dims(image, 0)
image = torch.Tensor(image)
image = image.to(DEVICE)
predicted = model(image)
plt.imshow(predicted[0].permute(1, 2, 0).detach().cpu().numpy().astype(np.uint8))
plt.show()

# %%
plt.imshow(image[0].permute(1, 2, 0).cpu().numpy().astype(np.uint8))
